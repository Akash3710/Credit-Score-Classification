# %% [markdown]
# ## Credit score

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load & Explore Data

# %%
data=pd.read_csv('train.csv')
data.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %%
data.describe()
# Out:
#                   ID    Customer_ID          Month            Age  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    80631.500000   25982.666640       4.500000      33.316340
# std     43301.486619   14340.543051       2.291299      10.764812
# min      5634.000000    1006.000000       1.000000      14.000000
# 25%     43132.750000   13664.500000       2.750000      24.000000
# 50%     80631.500000   25777.000000       4.500000      33.000000
# 75%    118130.250000   38385.000000       6.250000      42.000000
# max    155629.000000   50999.000000       8.000000      56.000000
#
#                 SSN  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  1.000000e+05  100000.000000          100000.000000      100000.000000
# mean   5.004617e+08   50505.123449            4197.270835           5.368820
# std    2.908267e+08   38299.422093            3186.432497           2.593314
# ...

# %%
data.shape
# Out:
# (100000, 28)

# %%
data.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['Credit_Mix'].value_counts()
# Out:
# Credit_Mix
# Standard    45848
# Good        30384
# Bad         23768
# Name: count, dtype: int64

# %% [markdown]
# Data Exploration

# %%
data['Credit_Score'].unique()
# Out:
# array(['Good', 'Standard', 'Poor'], dtype=object)

# %%
plt.pie(data['Credit_Score'].value_counts(),labels=data['Credit_Score'].unique(),autopct='%1.1f%%')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 20))
boxes = data.boxplot(column='Annual_Income', by='Occupation', ax=ax)

# %% [markdown]
# There’s not much difference in the credit scores of all occupations mentioned in the data

# %%
data.boxplot(column='Annual_Income', by='Credit_Score')
# Out:
# <Axes: title={'center': 'Annual_Income'}, xlabel='Credit_Score'>

# %% [markdown]
# as the annual income increases the credit score increasee

# %%
data.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
data.boxplot(column='Monthly_Inhand_Salary',by='Credit_Score')
# Out:
# <Axes: title={'center': 'Monthly_Inhand_Salary'}, xlabel='Credit_Score'>

# %% [markdown]
# as the Monthly Inhand Salary increases the credit score increases

# %%
data.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %%
data.boxplot(column='Age',by='Credit_Score')
# Out:
# <Axes: title={'center': 'Age'}, xlabel='Credit_Score'>

# %% [markdown]
# as the age increases it also increases

# %%
data.boxplot(column='Total_EMI_per_month',by='Credit_Score')
# Out:
# <Axes: title={'center': 'Total_EMI_per_month'}, xlabel='Credit_Score'>

# %%
data.boxplot(column='Monthly_Balance',by='Credit_Score')
# Out:
# <Axes: title={'center': 'Monthly_Balance'}, xlabel='Credit_Score'>

# %%
data.boxplot(column='Num_Bank_Accounts',by='Credit_Score')
# Out:
# <Axes: title={'center': 'Num_Bank_Accounts'}, xlabel='Credit_Score'>

# %% [markdown]
# having more than 5 is not good for credit score ,the person must have 2-3 to be good at credit score

# %%
data.boxplot(column="Interest_Rate", by="Credit_Score")
# Out:
# <Axes: title={'center': 'Interest_Rate'}, xlabel='Credit_Score'>

# %% [markdown]
# the avg rates for a good credit score is around 4-11% if the person have avg rate more than 15% the credit score will be bad

# %%
data.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
data.boxplot(column='Num_of_Loan',by='Credit_Score')
# Out:
# <Axes: title={'center': 'Num_of_Loan'}, xlabel='Credit_Score'>

# %% [markdown]
# it's good to have nu. of loans from 1-3

# %% [markdown]
# #### we found important for our model which is ["Annual_Income","Monthly_Inhand_Salary", "Num_Bank_Accounts", "Num_Credit_Card","Interest_Rate", "Num_of_Loan" "Delay_from_due_date","Num_of_Delayed_Payment","Credit_Mix", "Outstanding_Debt","Credit_History_Age", "Monthly_Balance"]

# %% [markdown]
# ## split the data

# %%
x=data[["Annual_Income", "Monthly_Inhand_Salary", 
        "Num_Bank_Accounts", "Num_Credit_Card", "Interest_Rate", "Num_of_Loan", 
        "Delay_from_due_date", "Num_of_Delayed_Payment","Credit_Mix", "Outstanding_Debt", "Credit_History_Age", "Monthly_Balance"]]

# %%
y=data.pop('Credit_Score')
y
# Out:
# 0            Good
# 1            Good
# 2            Good
# 3            Good
# 4            Good
#            ...
# 99995        Poor
# 99996        Poor
# 99997        Poor
# 99998    Standard
# 99999        Poor
# Name: Credit_Score, Length: 100000, dtype: object

# %%
y.head()
# Out:
# 0    Good
# 1    Good
# 2    Good
# 3    Good
# 4    Good
# Name: Credit_Score, dtype: object

# %%
x.head()
# Out:
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       19114.12            1824.843333                3.0              4.0
# 1       19114.12            1824.843333                3.0              4.0
# 2       19114.12            1824.843333                3.0              4.0
# 3       19114.12            1824.843333                3.0              4.0
# 4       19114.12            1824.843333                3.0              4.0
#
#    Interest_Rate  Num_of_Loan  Delay_from_due_date  Num_of_Delayed_Payment  \
# 0            3.0          4.0                  3.0                     7.0
# 1            3.0          4.0                  3.0                     4.0
# 2            3.0          4.0                  3.0                     7.0
# 3            3.0          4.0                  5.0                     4.0
# 4            3.0          4.0                  6.0                     4.0
#
# ...

# %%
x['Credit_Mix'].unique()
# Out:
# array(['Good', 'Standard', 'Bad'], dtype=object)

# %%
x['Credit_Mix']=x['Credit_Mix'].replace({'Good': 2,
                         'Standard':1,
                         'Bad':0})
# Out:
# C:\Users\USER07\AppData\Local\Temp\ipykernel_30608\4279679266.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   x['Credit_Mix']=x['Credit_Mix'].replace({'Good': 2,
# C:\Users\USER07\AppData\Local\Temp\ipykernel_30608\4279679266.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Credit_Mix']=x['Credit_Mix'].replace({'Good': 2,

# %%
x.head()
# Out:
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       19114.12            1824.843333                3.0              4.0
# 1       19114.12            1824.843333                3.0              4.0
# 2       19114.12            1824.843333                3.0              4.0
# 3       19114.12            1824.843333                3.0              4.0
# 4       19114.12            1824.843333                3.0              4.0
#
#    Interest_Rate  Num_of_Loan  Delay_from_due_date  Num_of_Delayed_Payment  \
# 0            3.0          4.0                  3.0                     7.0
# 1            3.0          4.0                  3.0                     4.0
# 2            3.0          4.0                  3.0                     7.0
# 3            3.0          4.0                  5.0                     4.0
# 4            3.0          4.0                  6.0                     4.0
#
# ...

# %% [markdown]
# ## Normalize Data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax=MinMaxScaler()

# %%
nums=["Annual_Income", "Monthly_Inhand_Salary", 
        "Num_Bank_Accounts", "Num_Credit_Card", "Interest_Rate", "Num_of_Loan", 
        "Delay_from_due_date", "Num_of_Delayed_Payment","Credit_Mix", "Outstanding_Debt", "Credit_History_Age", "Monthly_Balance"]

# %%
x[nums]=minmax.fit_transform(x[nums])
# Out:
# C:\Users\USER07\AppData\Local\Temp\ipykernel_30608\4022939370.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[nums]=minmax.fit_transform(x[nums])

# %%
x.head()
# Out:
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       0.069997               0.102087           0.272727         0.363636
# 1       0.069997               0.102087           0.272727         0.363636
# 2       0.069997               0.102087           0.272727         0.363636
# 3       0.069997               0.102087           0.272727         0.363636
# 4       0.069997               0.102087           0.272727         0.363636
#
#    Interest_Rate  Num_of_Loan  Delay_from_due_date  Num_of_Delayed_Payment  \
# 0       0.060606     0.444444             0.048387                    0.28
# 1       0.060606     0.444444             0.048387                    0.16
# 2       0.060606     0.444444             0.048387                    0.28
# 3       0.060606     0.444444             0.080645                    0.16
# 4       0.060606     0.444444             0.096774                    0.16
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.3 ,random_state=40)

# %%
x_train.shape
# Out:
# (70000, 12)

# %%
x_test.shape
# Out:
# (30000, 12)

# %%
y_train
# Out:
# 65538    Standard
# 20412    Standard
# 81336    Standard
# 24500        Good
# 61376        Poor
#            ...
# 56760        Good
# 93176    Standard
# 80037        Poor
# 30727        Good
# 11590    Standard
# Name: Credit_Score, Length: 70000, dtype: object

# %% [markdown]
# ## Model

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

y_train_enc = le.fit_transform(y_train)
y_test_enc = le.transform(y_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pandas as pd

models = {
    "Logistic Regression": LogisticRegression(
        multi_class='multinomial',
        solver='lbfgs',
        max_iter=1000
    ),
    "Random Forest": RandomForestClassifier(
        n_estimators=200,
        random_state=42
    ),
    "XGBoost": XGBClassifier(
        objective='multi:softmax',
        num_class=3,
        eval_metric='mlogloss',
        random_state=42
    )
}

results = []

for name, model in models.items():
    model.fit(x_train, y_train_enc)
    y_pred = model.predict(x_test)

    results.append({
        "Model": name,
        "Accuracy": accuracy_score(y_test_enc, y_pred),
        "Precision (weighted)": precision_score(y_test_enc, y_pred, average='weighted'),
        "Recall (weighted)": recall_score(y_test_enc, y_pred, average='weighted'),
        "F1-score (weighted)": f1_score(y_test_enc, y_pred, average='weighted')
    })

results_df = pd.DataFrame(results)
print(results_df)
# Out:
#                  Model  Accuracy  Precision (weighted)  Recall (weighted)  \
# 0  Logistic Regression  0.637000              0.635795           0.637000
# 1        Random Forest  0.807067              0.807307           0.807067
# 2              XGBoost  0.762800              0.764131           0.762800
#
#    F1-score (weighted)
# 0             0.630763
# 1             0.807077
# 2             0.763290
